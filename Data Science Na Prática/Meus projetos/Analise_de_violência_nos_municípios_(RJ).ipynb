# %% [markdown]
# <a href="https://colab.research.google.com/github/geovanemelo/data-science/blob/main/Analise_de_viol%C3%AAncia_nos_munic%C3%ADpios_(RJ).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/BaseMunicipioMensal.xltx')

# %%
df.head()
# Out:
#    fmun_cod                fmun  ...  registro_ocorrencias  fase
# 0   3300100      Angra dos Reis  ...                   561     3
# 1   3300159             Aperibé  ...                     0     3
# 2   3300209            Araruama  ...                   480     3
# 3   3300225               Areal  ...                     0     3
# 4   3300233  Armação dos Búzios  ...                   309     3
#
# [5 rows x 60 columns]

# %%
df.shape
# Out:
# (7820, 60)
