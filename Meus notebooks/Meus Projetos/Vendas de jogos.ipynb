# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv("vgsales.csv",index_col=False)

# %%
dados.head(30)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [raw]
# qual é as 5 maiores vendas registrada no japão?

# %%
JP_top5=dados.sort_values(ascending=False,by='JP_Sales').head(5)

# %%
JP_top5=JP_top5[['Name','Platform','Year','Genre','Publisher','JP_Sales']]

# %%
JP_top5
# Out:
#                              Name Platform    Year         Genre Publisher  \
# 4        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 12    Pokemon Gold/Pokemon Silver       GB  1999.0  Role-Playing  Nintendo
# 1               Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 6           New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 20  Pokemon Diamond/Pokemon Pearl       DS  2006.0  Role-Playing  Nintendo
#
#     JP_Sales
# 4      10.22
# 12      7.20
# 1       6.81
# 6       6.50
# 20      6.04

# %% [raw]
# qual é as 5 maiores vendas registradas no EUA?

# %%
NA_top5=dados.sort_values(ascending=False,by='NA_Sales').head()

# %%
NA_top5=NA_top5[['Name','Platform','Year','Genre','Publisher','NA_Sales']]

# %%
NA_top5
# Out:
#                 Name Platform    Year     Genre Publisher  NA_Sales
# 0         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 9          Duck Hunt      NES  1984.0   Shooter  Nintendo     26.93
# 5             Tetris       GB  1989.0    Puzzle  Nintendo     23.20
# 2     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85

# %% [raw]
# qual é as 5 maiores vendas registras na Europa?

# %%
EU_top5=dados.sort_values(ascending=False,by='EU_Sales').head()
EU_top5=EU_top5[['Name','Platform','Year','Genre','Publisher','EU_Sales']]

# %%
EU_top5
# Out:
#                   Name Platform    Year       Genre             Publisher  \
# 0           Wii Sports      Wii  2006.0      Sports              Nintendo
# 2       Mario Kart Wii      Wii  2008.0      Racing              Nintendo
# 3    Wii Sports Resort      Wii  2009.0      Sports              Nintendo
# 10          Nintendogs       DS  2005.0  Simulation              Nintendo
# 16  Grand Theft Auto V      PS3  2013.0      Action  Take-Two Interactive
#
#     EU_Sales
# 0      29.02
# 2      12.88
# 3      11.01
# 10     11.00
# 16      9.27

# %%
EU_top5[["Name","EU_Sales"]]
# Out:
#                   Name  EU_Sales
# 0           Wii Sports     29.02
# 2       Mario Kart Wii     12.88
# 3    Wii Sports Resort     11.01
# 10          Nintendogs     11.00
# 16  Grand Theft Auto V      9.27

# %% [raw]
# Qual o genero mais vendidos de games no estados unidos?

# %%
Genre_Na=dados[["Genre","NA_Sales"]]

# %%
Genre_Na
# Out:
#               Genre  NA_Sales
# 0            Sports     41.49
# 1          Platform     29.08
# 2            Racing     15.85
# 3            Sports     15.75
# 4      Role-Playing     11.27
# ...             ...       ...
# 16593      Platform      0.01
# 16594       Shooter      0.01
# 16595        Racing      0.00
# 16596        Puzzle      0.00
# 16597      Platform      0.01
#
# [16598 rows x 2 columns]

# %%
Genre_Na["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
Sports_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Sports"]

# %%
Plataform_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Plataform"]
Racing_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Racing"]
RolePlaying_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Role-Playing"]
Puzzle_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Puzzle"]
Misc_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Misc"]
Shooter_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Shooter"]
Simulation_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Simulation"]
Action_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Action"]
Fighting_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Fighting"]
Adventure_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Adventure"]
Strategy_Genre_Na=Genre_Na[Genre_Na["Genre"] == "Strategy"]

# %%
Genre_Na
# Out:
#               Genre  NA_Sales
# 0            Sports     41.49
# 1          Platform     29.08
# 2            Racing     15.85
# 3            Sports     15.75
# 4      Role-Playing     11.27
# ...             ...       ...
# 16593      Platform      0.01
# 16594       Shooter      0.01
# 16595        Racing      0.00
# 16596        Puzzle      0.00
# 16597      Platform      0.01
#
# [16598 rows x 2 columns]

# %%
Genre_Na.groupby("Genre")

# %%
por_genro=Genre_Na.groupby(by="Genre")

# %%
por_genro.describe()
# Out:
#              NA_Sales
#                 count      mean       std  min   25%   50%   75%    max
# Genre
# Action         3316.0  0.264726  0.566890  0.0  0.02  0.10  0.26   9.63
# Adventure      1286.0  0.082271  0.274674  0.0  0.00  0.00  0.07   6.16
# Fighting        848.0  0.263667  0.516148  0.0  0.00  0.08  0.29   6.75
# Misc           1739.0  0.235906  0.690878  0.0  0.00  0.08  0.21  14.97
# Platform        886.0  0.504571  1.502039  0.0  0.05  0.14  0.44  29.08
# Puzzle          582.0  0.212680  1.057669  0.0  0.01  0.05  0.14  23.20
# Racing         1249.0  0.287766  0.742523  0.0  0.03  0.10  0.27  15.85
# Role-Playing   1488.0  0.219946  0.672721  0.0  0.00  0.04  0.16  11.27
# Shooter        1310.0  0.444733  1.201147  0.0  0.03  0.12  0.37  26.93
# Simulation      867.0  0.211430  0.466698  0.0  0.00  0.07  0.24   9.07
# Sports         2346.0  0.291283  1.041024  0.0  0.02  0.11  0.30  41.49
# Strategy        681.0  0.100881  0.298956  0.0  0.00  0.00  0.08   3.18

# %%
todos_generos=Genre_Na["Genre"].unique()

# %%
sum(Sports_Genre_Na['NA_Sales'])
# Out:
# 683.3499999999967

# %%
todos_generos
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
Genre_Na
# Out:
#               Genre  NA_Sales
# 0            Sports     41.49
# 1          Platform     29.08
# 2            Racing     15.85
# 3            Sports     15.75
# 4      Role-Playing     11.27
# ...             ...       ...
# 16593      Platform      0.01
# 16594       Shooter      0.01
# 16595        Racing      0.00
# 16596        Puzzle      0.00
# 16597      Platform      0.01
#
# [16598 rows x 2 columns]

# %%
grouped=Genre_Na.groupby('Genre')

# %%
grouped.sum()
# Out:
#               NA_Sales
# Genre
# Action          877.83
# Adventure       105.80
# Fighting        223.59
# Misc            410.24
# Platform        447.05
# Puzzle          123.78
# Racing          359.42
# Role-Playing    327.28
# Shooter         582.60
# Simulation      183.31
# Sports          683.35
# Strategy         68.70

# %%
GENEROSMAISVENDIDOSNA=grouped.sum().sort_values(by="NA_Sales",ascending=False)

# %%
GENEROSMAISVENDIDOSNA.head(1)
# Out:
#         NA_Sales
# Genre
# Action    877.83

# %% [markdown]
# # Qual os tres generos de games mais vendidos no estados unidos?

# %%
GENEROSMAISVENDIDOSNA.head(3)
# Out:
#          NA_Sales
# Genre
# Action     877.83
# Sports     683.35
# Shooter    582.60

# %% [raw]
# Quais são os cincos jogos mais vendidos do genero mais vendido(action)?

# %%
action=dados[['Name','Platform','Genre','NA_Sales']]

# %%
action
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue       GB
# ...                                                 ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA
# 16594                     Men in Black II: Alien Escape       GC
# 16595  SCORE International Baja 1000: The Official Game      PS2
# 16596                                        Know How 2       DS
# 16597                                  Spirits & Spells      GBA
#
#               Genre  NA_Sales
# 0            Sports     41.49
# 1          Platform     29.08
# 2            Racing     15.85
# 3            Sports     15.75
# ...

# %%
action=action[action["Genre"]=="Action"]

# %%
action
# Out:
#                                                     Name Platform   Genre  \
# 16                                    Grand Theft Auto V      PS3  Action
# 17                         Grand Theft Auto: San Andreas      PS2  Action
# 23                                    Grand Theft Auto V     X360  Action
# 24                           Grand Theft Auto: Vice City      PS2  Action
# 38                                  Grand Theft Auto III      PS2  Action
# ...                                                  ...      ...     ...
# 16564      Original Frisbee Disc Sports: Ultimate & Golf       DS  Action
# 16567  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS  Action
# 16582                                    Planet Monsters      GBA  Action
# 16583                                     Carmageddon 64      N64  Action
# 16589  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV  Action
#
#        NA_Sales
# 16         7.01
# 17         9.43
# 23         9.63
# ...

# %%
CINCOGAMESDEACAOMAISVENDIDOSNA=action.sort_values(by="NA_Sales",ascending=False).head(5)

# %%
CINCOGAMESDEACAOMAISVENDIDOSNA
# Out:
#                              Name Platform   Genre  NA_Sales
# 23             Grand Theft Auto V     X360  Action      9.63
# 17  Grand Theft Auto: San Andreas      PS2  Action      9.43
# 24    Grand Theft Auto: Vice City      PS2  Action      8.41
# 16             Grand Theft Auto V      PS3  Action      7.01
# 38           Grand Theft Auto III      PS2  Action      6.99

# %% [markdown]
# # Quais são os cincos jogos mais vendidos do genero mais vendido(action) no na?

# %%
CINCOGAMESDEACAOMAISVENDIDOSNA
# Out:
#                              Name Platform   Genre  NA_Sales
# 23             Grand Theft Auto V     X360  Action      9.63
# 17  Grand Theft Auto: San Andreas      PS2  Action      9.43
# 24    Grand Theft Auto: Vice City      PS2  Action      8.41
# 16             Grand Theft Auto V      PS3  Action      7.01
# 38           Grand Theft Auto III      PS2  Action      6.99

# %% [raw]
# Faça duelos entre publicadoras. Quem vendeu mais na Europa: UBISOFT ou NINTENDO?

# %%
dados["Publisher"].value_counts().head(10)
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
# THQ                              715
# Nintendo                         703
# Sony Computer Entertainment      683
# Sega                             639
# Take-Two Interactive             413
# Name: Publisher, dtype: int64

# %%
VENDASPUBLICADOREUROPA=dados[["Name","Publisher","EU_Sales"]]

# %%
VENDASPUBLICADOREUROPA
# Out:
#                                                    Name   Publisher  EU_Sales
# 0                                            Wii Sports    Nintendo     29.02
# 1                                     Super Mario Bros.    Nintendo      3.58
# 2                                        Mario Kart Wii    Nintendo     12.88
# 3                                     Wii Sports Resort    Nintendo     11.01
# 4                              Pokemon Red/Pokemon Blue    Nintendo      8.89
# ...                                                 ...         ...       ...
# 16593                Woody Woodpecker in Crazy Castle 5       Kemco      0.00
# 16594                     Men in Black II: Alien Escape  Infogrames      0.00
# 16595  SCORE International Baja 1000: The Official Game  Activision      0.00
# 16596                                        Know How 2    7G//AMES      0.01
# 16597                                  Spirits & Spells     Wanadoo      0.00
#
# [16598 rows x 3 columns]

# %%
VENDASPUBLICADOREUROPA_UBISOFT=VENDASPUBLICADOREUROPA[VENDASPUBLICADOREUROPA["Publisher"]=="Ubisoft"]

# %%
VENDASPUBLICADOREUROPA_UBISOFT
# Out:
#                                             Name Publisher  EU_Sales
# 60                                  Just Dance 3   Ubisoft      3.15
# 68                                  Just Dance 2   Ubisoft      2.89
# 102                                   Just Dance   Ubisoft      3.03
# 111                                 Just Dance 4   Ubisoft      2.21
# 128                         Assassin's Creed III   Ubisoft      2.56
# ...                                          ...       ...       ...
# 16505  Rabbids Invasion: The Interactive TV Show   Ubisoft      0.01
# 16514       National Geographic Panda (JP sales)   Ubisoft      0.00
# 16544           Imagine Figure Skater (JP sales)   Ubisoft      0.00
# 16584                           Bust-A-Move 3000   Ubisoft      0.00
# 16591                        Myst IV: Revelation   Ubisoft      0.00
#
# [921 rows x 3 columns]

# %%
VENDASPUBLICADOREUROPA_UBISOFT["EU_Sales"].sum()
# Out:
# 163.32

# %%
VENDASPUBLICADOREUROPA_NINTENDO=VENDASPUBLICADOREUROPA[VENDASPUBLICADOREUROPA["Publisher"]=="Nintendo"]

# %%
VENDASPUBLICADOREUROPA_NINTENDO["EU_Sales"].sum()
# Out:
# 418.7399999999999

# %%
def word_string(title):
    if 'fifa' in title.lower():
        return True
    else:
        return False

# %%
DADOSDOFIFA=dados[(dados['Name'].apply(lambda x: word_string(x)))]

# %%
DADOSDOFIFA
# Out:
#         Rank                                Name Platform    Year   Genre  \
# 77        78                             FIFA 16      PS4  2015.0  Sports
# 82        83                      FIFA Soccer 13      PS3  2012.0  Action
# 112      113                             FIFA 14      PS3  2013.0  Sports
# 121      122                             FIFA 12      PS3  2011.0  Sports
# 124      125                             FIFA 15      PS4  2014.0  Sports
# ...      ...                                 ...      ...     ...     ...
# 13611  13613  FIFA Soccer 2003 (weekly jp sales)      PS2  2002.0  Sports
# 13851  13853         FIFA World Cup Germany 2006       DS  2006.0  Sports
# 14251  14254        FIFA World Cup: Germany 2006      GBA  2006.0  Sports
# 15205  15208                      FIFA Soccer 09       PC  2008.0  Sports
# 15837  15840                      FIFA Soccer 08       PC  2007.0  Sports
#
#              Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [raw]
# Qual o fifa mais vendido no mundo?

# %%
DADOSDOFIFA.sort_values(by="Global_Sales",ascending=False).head(5)
# Out:
#      Rank            Name Platform    Year   Genre        Publisher  NA_Sales  \
# 77     78         FIFA 16      PS4  2015.0  Sports  Electronic Arts      1.11
# 82     83  FIFA Soccer 13      PS3  2012.0  Action  Electronic Arts      1.06
# 112   113         FIFA 14      PS3  2013.0  Sports  Electronic Arts      0.78
# 121   122         FIFA 12      PS3  2011.0  Sports  Electronic Arts      0.84
# 124   125         FIFA 15      PS4  2014.0  Sports  Electronic Arts      0.79
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77       6.06      0.06         1.26          8.49
# 82       5.05      0.13         2.01          8.24
# 112      4.32      0.07         1.73          6.90
# 121      4.32      0.11         1.42          6.69
# 124      4.29      0.05         1.47          6.59

# %% [raw]
# Faça um gráfico as vendas globais do fifa 16 vendidos na plataforma ps4 e Xbox One

# %%
def word_string(title):
    if 'fifa 16' in title.lower():
        return True
    else:
        return False

# %%
dados[(dados['Name'].apply(lambda x: word_string(x)))]
# Out:
#       Rank     Name Platform    Year   Genre        Publisher  NA_Sales  \
# 77      78  FIFA 16      PS4  2015.0  Sports  Electronic Arts      1.11
# 416    417  FIFA 16     XOne  2015.0  Sports  Electronic Arts      0.88
# 513    514  FIFA 16      PS3  2015.0  Sports  Electronic Arts      0.40
# 1063  1065  FIFA 16     X360  2015.0  Sports  Electronic Arts      0.55
# 8134  8136  FIFA 16       PC  2015.0  Sports  Electronic Arts      0.04
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 77        6.06      0.06         1.26          8.49
# 416       2.11      0.00         0.23          3.23
# 513       1.98      0.05         0.42          2.85
# 1063      1.01      0.00         0.13          1.69
# 8134      0.13      0.00         0.01          0.18

# %%
DADOSDOFIFA16=dados[(dados['Name'].apply(lambda x: word_string(x)))]

# %%
DADOSDEVENDASGLOBAISPS4XBOXONE=DADOSDOFIFA16.query("Platform == 'PS4' | Platform == 'XOne'")

# %%
DADOSDEVENDASGLOBAISPS4XBOXONE=DADOSDEVENDASGLOBAISPS4XBOXONE[["Name","Platform","Global_Sales"]]

# %%
DADOSDEVENDASGLOBAISPS4XBOXONE.reset_index(drop=True,inplace=True)

# %%
DADOSDEVENDASGLOBAISPS4XBOXONE
# Out:
#       Name Platform  Global_Sales
# 0  FIFA 16      PS4          8.49
# 1  FIFA 16     XOne          3.23

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
DADOSDEVENDASGLOBAISPS4XBOXONE.iloc[0:1]
# Out:
#       Name Platform  Global_Sales
# 0  FIFA 16      PS4          8.49

# %% [raw]
# Faça um gráfico de vendas globais do just dance para xbox360(baseado no ano)(0,4)

# %%
def word_string(title):
    if 'just dance' in title.lower():
        return True
    else:
        return False

# %%
JUSTDANCE=dados[(dados['Name'].apply(lambda x: word_string(x)))]

# %%
JUSTDANCE=JUSTDANCE.query('Platform=="X360"')

# %%
JUSTDANCE=JUSTDANCE[["Name","Year","Global_Sales"]]

# %%
JUSTDANCE
# Out:
#                              Name    Year  Global_Sales
# 838                  Just Dance 3  2011.0          2.03
# 1703                 Just Dance 4  2012.0          1.19
# 2108              Just Dance 2014  2013.0          0.98
# 3187              Just Dance 2015  2014.0          0.63
# 4761            Just Dance Kids 2  2011.0          0.41
# 5226              Just Dance 2016  2015.0          0.36
# 8630     Just Dance: Disney Party  2012.0          0.16
# 11865  Just Dance: Disney Party 2  2015.0          0.07

# %%
JUSTDANCE.reset_index(drop=True,inplace=True)

# %%
JUSTDANCE=JUSTDANCE.sort_values(by="Year")

# %%
JUSTDANCEGROUPEDYEAR=JUSTDANCE.groupby(by="Year")

# %%
JUSTDANCEGROUPEDYEAR=JUSTDANCEGROUPEDYEAR.sum()

# %%
JUSTDANCEGROUPEDYEAR
# Out:
#         Global_Sales
# Year
# 2011.0          2.44
# 2012.0          1.35
# 2013.0          0.98
# 2014.0          0.63
# 2015.0          0.43

# %%
plt.plot(JUSTDANCEGROUPEDYEAR,'r--')
plt.xlabel("VENDAS GLOBAIS")
plt.ylabel("ANO")
plt.title("Gráfico X360")
# Out:
# Text(0.5, 1.0, 'Gráfico X360')

# %%
JUSTDANCE2=dados[(dados['Name'].apply(lambda x: word_string(x)))]

# %%
JUSTDANCE2=JUSTDANCE2.query('Platform=="PS3"')

# %%
JUSTDANCE2GROUPEDYEAR=JUSTDANCE2.groupby(by='Year')

# %%
JUSTDANCE2GROUPEDYEAR=JUSTDANCE2GROUPEDYEAR.sum()

# %%
plt.plot(JUSTDANCE2GROUPEDYEAR,'r--')
plt.xlabel("VENDAS GLOBAIS")
plt.ylabel("ANO")
plt.title("Gráfico PS3")
# Out:
# Text(0.5, 1.0, 'Gráfico PS3')

# %%
plt.subplot(1,2,1)
plt.plot(JUSTDANCEGROUPEDYEAR,'g--')
plt.subplot(1,2,2)
plt.plot(JUSTDANCE2GROUPEDYEAR,'b--')

# %%
dados
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [raw]
# Faça analise com gráficos dos 5 jogos mais vendidos de luta de ps4

# %%
dados["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
dados[['Name','Platform','Genre','Global_Sales']]
# Out:
#                                                    Name Platform  \
# 0                                            Wii Sports      Wii
# 1                                     Super Mario Bros.      NES
# 2                                        Mario Kart Wii      Wii
# 3                                     Wii Sports Resort      Wii
# 4                              Pokemon Red/Pokemon Blue       GB
# ...                                                 ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA
# 16594                     Men in Black II: Alien Escape       GC
# 16595  SCORE International Baja 1000: The Official Game      PS2
# 16596                                        Know How 2       DS
# 16597                                  Spirits & Spells      GBA
#
#               Genre  Global_Sales
# 0            Sports         82.74
# 1          Platform         40.24
# 2            Racing         35.82
# 3            Sports         33.00
# ...

# %%
JOGOSDELUTA=dados[['Name','Platform','Genre','Global_Sales']].query("Genre=='Fighting'").reset_index(drop=True)

# %%
JOGOSDELUTA
# Out:
#                                          Name Platform     Genre  Global_Sales
# 0                     Super Smash Bros. Brawl      Wii  Fighting         13.04
# 1         Super Smash Bros. for Wii U and 3DS      3DS  Fighting          7.45
# 2                                    Tekken 3       PS  Fighting          7.16
# 3                     Super Smash Bros. Melee       GC  Fighting          7.07
# 4        Street Fighter II: The World Warrior     SNES  Fighting          6.30
# ..                                        ...      ...       ...           ...
# 843                  Dragon Ball Z for Kinect     X360  Fighting          0.01
# 844             Samurai Shodown: Warrios Rage       PS  Fighting          0.01
# 845                           Battle Fantasia      PS3  Fighting          0.01
# 846  Mahou Sensei Negima!? Neo-Pactio Fight!!      Wii  Fighting          0.01
# 847            Mortal Kombat: Deadly Alliance      GBA  Fighting          0.01
#
# [848 rows x 4 columns]

# %%
JOGOSDELUTA.sort_values(by="Global_Sales",ascending=False)
# Out:
#                                                 Name Platform     Genre  \
# 0                            Super Smash Bros. Brawl      Wii  Fighting
# 1                Super Smash Bros. for Wii U and 3DS      3DS  Fighting
# 2                                           Tekken 3       PS  Fighting
# 3                            Super Smash Bros. Melee       GC  Fighting
# 4               Street Fighter II: The World Warrior     SNES  Fighting
# ..                                               ...      ...       ...
# 826                                    Mortal Kombat       PC  Fighting
# 825                   One Piece: Daikaizoku Coliseum      3DS  Fighting
# 824                 Blazblue: Continuum Shift Extend      PSP  Fighting
# 823  Shinseiki Evangelion: Battle Orchestra Portable      PSP  Fighting
# 847                   Mortal Kombat: Deadly Alliance      GBA  Fighting
#
#      Global_Sales
# 0           13.04
# 1            7.45
# 2            7.16
# 3            7.07
# ...

# %%
JOGOSDELUTAPS4=JOGOSDELUTA.query("Platform == 'PS4'").head()

# %%
JOGOSDELUTAPS4
# Out:
#                                          Name Platform     Genre  Global_Sales
# 30                            Mortal Kombat X      PS4  Fighting          2.70
# 114  Naruto Shippuden: Ultimate Ninja Storm 4      PS4  Fighting          1.06
# 116                    Dragon Ball: XenoVerse      PS4  Fighting          1.05
# 136                  Injustice: Gods Among Us      PS4  Fighting          0.87
# 145                          Street Fighter V      PS4  Fighting          0.82

# %%
(JOGOSDELUTAPS4["Name"])
# Out:
# 30                              Mortal Kombat X
# 114    Naruto Shippuden: Ultimate Ninja Storm 4
# 116                      Dragon Ball: XenoVerse
# 136                    Injustice: Gods Among Us
# 145                            Street Fighter V
# Name: Name, dtype: object

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
JOGOSDELUTAXBOXONE=JOGOSDELUTA.query("Platform == 'XOne'").head()

# %%
JOGOSDELUTAXBOXONE
# Out:
#                                          Name Platform     Genre  Global_Sales
# 85                            Mortal Kombat X     XOne  Fighting          1.35
# 337                    Dragon Ball: XenoVerse     XOne  Fighting          0.31
# 359  Naruto Shippuden: Ultimate Ninja Storm 4     XOne  Fighting          0.28
# 444                            Fighter Within     XOne  Fighting          0.19
# 625                           Dead or Alive 5     XOne  Fighting          0.08

# %%
DADOSDOFIFAXBOXONE=DADOSDOFIFA.query("Platform=='XOne'")

# %%
DADOSDOFIFAXBOXONE.reset_index(drop=True,inplace=True)

# %%
DADOSDOFIFAXBOXONE=DADOSDOFIFAXBOXONE[['Name','Year','Global_Sales']]

# %%
DADOSDOFIFAXBOXONE=DADOSDOFIFAXBOXONE.sort_values(by="Name")

# %%
DADOSDOFIFAXBOXONE=DADOSDOFIFAXBOXONE.iloc[1:]

# %%
DADOSDOFIFAXBOXONE
# Out:
#       Name    Year  Global_Sales
# 1  FIFA 15  2014.0          2.15
# 0  FIFA 16  2015.0          3.23
# 2  FIFA 17  2016.0          1.53

# %%
def word_string(title):
    if 'pro evolution soccer' in title.lower():
        return True
    else:
        return False

# %%
DADOSPES=dados[(dados['Name'].apply(lambda x: word_string(x)))]

# %%
DADOSPES=DADOSPES.query('Platform=="XOne"')[['Name','Year','Global_Sales']]

# %%
DADOSPES.reset_index(drop=True,inplace=True)

# %%
DADOSPES
# Out:
#                         Name    Year  Global_Sales
# 0  Pro Evolution Soccer 2015  2014.0          0.14
# 1  Pro Evolution Soccer 2016  2015.0          0.10
# 2  Pro Evolution Soccer 2017  2016.0          0.03

# %% [raw]
# faça gráfico de vendas de jogos da nintendo por ano

# %%
dados.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
DADOSNINTENDO=dados[['Name','Publisher','Year','Global_Sales']]

# %%
DADOSNINTENDO=DADOSNINTENDO.query("Publisher == 'Nintendo'")

# %%
DADOSNINTENDO
# Out:
#                                                     Name Publisher    Year  \
# 0                                             Wii Sports  Nintendo  2006.0
# 1                                      Super Mario Bros.  Nintendo  1985.0
# 2                                         Mario Kart Wii  Nintendo  2008.0
# 3                                      Wii Sports Resort  Nintendo  2009.0
# 4                               Pokemon Red/Pokemon Blue  Nintendo  1996.0
# ...                                                  ...       ...     ...
# 16269                           Slide Adventure: Mag Kid  Nintendo  2007.0
# 16357               Mario vs. Donkey Kong: Tipping Stars  Nintendo  2015.0
# 16456                           Art Academy: Home Studio  Nintendo  2015.0
# 16473                                    Captain Rainbow  Nintendo  2008.0
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...  Nintendo  2015.0
#
#        Global_Sales
# 0             82.74
# 1             40.24
# ...

# %%
DADOSNINTENDOGROUPED=DADOSNINTENDO.groupby(by="Year")

# %%
DADOSNINTENDOGROUPEDBYYEAR=DADOSNINTENDOGROUPED.sum()

# %%
DADOSNINTENDOGROUPEDBYYEAR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 34 entries, 1983.0 to 2016.0
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Global_Sales  34 non-null     float64
# dtypes: float64(1)
# memory usage: 544.0 bytes

# %%
import seaborn as sns

# %%
DADOSNINTENDO
# Out:
#                                                     Name Publisher    Year  \
# 0                                             Wii Sports  Nintendo  2006.0
# 1                                      Super Mario Bros.  Nintendo  1985.0
# 2                                         Mario Kart Wii  Nintendo  2008.0
# 3                                      Wii Sports Resort  Nintendo  2009.0
# 4                               Pokemon Red/Pokemon Blue  Nintendo  1996.0
# ...                                                  ...       ...     ...
# 16269                           Slide Adventure: Mag Kid  Nintendo  2007.0
# 16357               Mario vs. Donkey Kong: Tipping Stars  Nintendo  2015.0
# 16456                           Art Academy: Home Studio  Nintendo  2015.0
# 16473                                    Captain Rainbow  Nintendo  2008.0
# 16542  Mario & Luigi: Paper Jam & Mario Kart 7 Double...  Nintendo  2015.0
#
#        Global_Sales
# 0             82.74
# 1             40.24
# ...

# %%
sns.displot(DADOSNINTENDO['Year'],bins=34)

# %%
sns.jointplot(y='Year',x='Global_Sales',data=DADOSNINTENDO)

# %%
sns.jointplot(y='Year',x='Global_Sales',data=DADOSNINTENDO,kind='reg')

# %%
sns.jointplot(y='Year',x='Global_Sales',data=DADOSNINTENDO,kind='hex')

# %%
sns.pairplot(DADOSNINTENDO)

# %%
dados.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
dados["Publisher"].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %%
dados.query("Publisher == 'Activision'| Publisher == 'Ubisoft' ")
# Out:
#         Rank                                              Name Platform  \
# 29        30                    Call of Duty: Modern Warfare 3     X360
# 31        32                           Call of Duty: Black Ops     X360
# 33        34                         Call of Duty: Black Ops 3      PS4
# 34        35                        Call of Duty: Black Ops II      PS3
# 35        36                        Call of Duty: Black Ops II     X360
# ...      ...                                               ...      ...
# 16537  16540                   Transformers: Fall of Cybertron       PC
# 16544  16547                  Imagine Figure Skater (JP sales)       DS
# 16584  16587                                  Bust-A-Move 3000       GC
# 16591  16594                               Myst IV: Revelation       PC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
ACTIVISIONXUBISOFT=dados.query("Publisher == 'Activision'| Publisher == 'Ubisoft' ")

# %%
ACTIVISIONXUBISOFT=ACTIVISIONXUBISOFT[['Name','Year','Publisher','Global_Sales']]

# %%
ACTIVISIONXUBISOFT.head()
# Out:
#                               Name    Year   Publisher  Global_Sales
# 29  Call of Duty: Modern Warfare 3  2011.0  Activision         14.76
# 31         Call of Duty: Black Ops  2010.0  Activision         14.64
# 33       Call of Duty: Black Ops 3  2015.0  Activision         14.24
# 34      Call of Duty: Black Ops II  2012.0  Activision         14.03
# 35      Call of Duty: Black Ops II  2012.0  Activision         13.73

# %% [raw]
# compare as vendas da activision e ubisoft

# %%
teste=ACTIVISIONXUBISOFT.groupby(by="Publisher")

# %%
ACTIVISIONXUBISOFTGROUPED=teste.sum()
ACTIVISIONXUBISOFTGROUPED
# Out:
#                  Year  Global_Sales
# Publisher
# Activision  1938979.0        727.46
# Ubisoft     1843194.0        474.72

# %%
sns.barplot(x="Publisher",y="Global_Sales",data=ACTIVISIONXUBISOFT)
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='Global_Sales'>

# %%
sns.countplot(x='Publisher', data=ACTIVISIONXUBISOFT) #quantidade de jogos lançados
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='count'>

# %%
sns.violinplot(x='Publisher',y='Year',data=ACTIVISIONXUBISOFT)
# Out:
# <AxesSubplot:xlabel='Publisher', ylabel='Year'>

# %%
sns.swarmplot(x='Publisher',y='Year',data=ACTIVISIONXUBISOFT)
# Out:
# c:\users\família\appdata\local\programs\python\python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 52.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\família\appdata\local\programs\python\python37\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Publisher', ylabel='Year'>

# %%
ACTIVISIONXUBISOFT.query("Publisher == 'Ubisoft'").sort_values(by="Year",ascending=False)
# Out:
#                               Name    Year Publisher  Global_Sales
# 5957        Imagine: Makeup Artist  2020.0   Ubisoft          0.29
# 2434               Far Cry: Primal  2016.0   Ubisoft          0.85
# 16448  Assassin's Creed Chronicles  2016.0   Ubisoft          0.01
# 9250               Far Cry: Primal  2016.0   Ubisoft          0.14
# 12925                       ZombiU  2016.0   Ubisoft          0.05
# ...                            ...     ...       ...           ...
# 8684                  Street Racer  1996.0   Ubisoft          0.16
# 462                         Rayman  1995.0   Ubisoft          3.03
# 2528      Shaun White Snowboarding     NaN   Ubisoft          0.82
# 7946             Star Trek: Legacy     NaN   Ubisoft          0.19
# 8376          Sword of the Samurai     NaN   Ubisoft          0.17
#
# [921 rows x 4 columns]

# %%
dados["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
dados[["Genre","Year","Global_Sales"]]
# Out:
#               Genre    Year  Global_Sales
# 0            Sports  2006.0         82.74
# 1          Platform  1985.0         40.24
# 2            Racing  2008.0         35.82
# 3            Sports  2009.0         33.00
# 4      Role-Playing  1996.0         31.37
# ...             ...     ...           ...
# 16593      Platform  2002.0          0.01
# 16594       Shooter  2003.0          0.01
# 16595        Racing  2008.0          0.01
# 16596        Puzzle  2010.0          0.01
# 16597      Platform  2003.0          0.01
#
# [16598 rows x 3 columns]

# %%
pf=dados[["Genre","Year","Global_Sales"]].pivot_table(values='Global_Sales',index='Genre',columns='Year')

# %%
pf
# Out:
# Year          1980.0  1981.0    1982.0    1983.0     1984.0   1985.0  \
# Genre
# Action        0.3400  0.5936  0.362222  0.408571   1.850000   1.7600
# Adventure        NaN     NaN       NaN  0.400000        NaN      NaN
# Fighting      0.7700     NaN       NaN       NaN        NaN   1.0500
# Misc          0.6775     NaN  0.870000  2.140000   1.450000      NaN
# Platform         NaN  2.3100  1.006000  1.386000   0.690000  10.7925
# Puzzle           NaN  1.1200  3.343333  0.780000   1.046667   0.8025
# Racing           NaN  0.4800  0.785000       NaN   1.983333      NaN
# Role-Playing     NaN     NaN       NaN       NaN        NaN      NaN
# Shooter       3.5350  1.0040  0.758000  0.480000  10.366667   1.0000
# Simulation       NaN  0.4500       NaN       NaN        NaN   0.0300
# Sports        0.4900  0.1975  0.525000  3.200000   3.090000   1.9600
# Strategy         NaN     NaN       NaN       NaN        NaN      NaN
#
# ...

# %%
dados
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
dados.query("Year > 1999")[["Year","Genre","Global_Sales"]]
# Out:
#          Year     Genre  Global_Sales
# 0      2006.0    Sports         82.74
# 2      2008.0    Racing         35.82
# 3      2009.0    Sports         33.00
# 6      2006.0  Platform         30.01
# 7      2006.0      Misc         29.02
# ...       ...       ...           ...
# 16593  2002.0  Platform          0.01
# 16594  2003.0   Shooter          0.01
# 16595  2008.0    Racing          0.01
# 16596  2010.0    Puzzle          0.01
# 16597  2003.0  Platform          0.01
#
# [14353 rows x 3 columns]

# %%
pf=dados.query("Year > 1999 & Year < 2017 " )[["Year","Genre","Global_Sales"]]

# %%
pf=pf.pivot_table(values='Global_Sales',index='Genre',columns='Year')

# %%
pf
# Out:
# Year            2000.0    2001.0    2002.0    2003.0    2004.0    2005.0  \
# Genre
# Action        0.773636  0.886418  0.694160  0.471736  0.610080  0.446302
# Adventure     0.186250  0.434286  0.263095  0.178333  0.223077  0.203095
# Fighting      0.697241  1.006667  0.463333  0.539318  0.430256  0.458605
# Misc          0.777000  0.630769  0.348222  0.449434  0.368471  0.532522
# Platform      0.669167  0.913488  0.597013  0.492989  0.717273  0.283855
# Puzzle        0.318333  0.533333  0.267000  0.302500  0.337200  0.619697
# Racing        0.464884  0.786056  0.293204  0.478807  0.674085  0.732727
# Role-Playing  1.001034  0.538049  0.820545  0.630833  0.899167  0.402113
# Shooter       0.340500  0.688056  0.614937  0.371781  0.533523  0.433333
# Simulation    0.225333  0.697857  0.568947  0.606000  0.401852  1.296579
# Sports        0.508519  0.535729  0.347979  0.448880  0.600755  0.488033
# Strategy      0.531250  0.377500  0.252727  0.215946  0.224687  0.185172
#
# ...

# %%
pf[2016.0].fillna(value=pf[2016.0].mean(),inplace=True)

# %%
sns.heatmap(pf,cmap='magma',linecolor='gray', linewidths=1)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Genre'>
