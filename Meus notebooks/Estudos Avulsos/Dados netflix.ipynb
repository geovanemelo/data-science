# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
netflix = pd.read_csv("netflix_titles.csv")

# %%
netflix.head(10)
# Out:
#       type                                    title  \
# 0    Movie  Norm of the North: King Sized Adventure
# 1    Movie               Jandino: Whatever it Takes
# 2  TV Show                       Transformers Prime
# 3  TV Show         Transformers: Robots in Disguise
# 4    Movie                             #realityhigh
# 5  TV Show                                  Apaches
# 6    Movie                                 Automata
# 7    Movie       Fabrizio Copano: Solo pienso en mi
# 8  TV Show                             Fire Chasers
# 9    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 8                              NaN
# ...

# %%
del netflix['description']

# %% [markdown]
# # trabalhe com  filmes  de 2019

# %%
filmes2019=netflix.query("type == 'Movie' & release_year == 2019")

# %% [raw]
# Quantos filmes foram lançandos em 2019?

# %%
filmes2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 5469
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          400 non-null    object
#  1   title         400 non-null    object
#  2   director      377 non-null    object
#  3   cast          355 non-null    object
#  4   country       350 non-null    object
#  5   date_added    400 non-null    object
#  6   release_year  400 non-null    int64
#  7   rating        400 non-null    object
#  8   duration      400 non-null    object
#  9   listed_in     400 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 34.4+ KB

# %%
#compare a quantidade filmes lançado no brasil, china,india e estados unidos

# %%
s=filmesbrnainchi["country"].value_counts()

# %%
s
# Out:
# United States    160
# India             49
# Brazil             7
# China              3
# Name: country, dtype: int64

# %%
filmesbrnainchigrouped=pd.DataFrame({'country':s.index,'quantify':s.values})

# %%
filmesbrnainchigrouped
# Out:
#          country  quantify
# 0  United States       160
# 1          India        49
# 2         Brazil         7
# 3          China         3

# %%
sns.barplot(x='quantify',y='country',data=filmesbrnainchigrouped,orient="h")
# Out:
# <AxesSubplot:xlabel='quantify', ylabel='country'>

# %%
sns.countplot(x='country',data=filmesbrnainchi)
# Out:
# <AxesSubplot:xlabel='country', ylabel='count'>

# %%
filmes2019
# Out:
#        type                                             title  \
# 0     Movie           Norm of the North: King Sized Adventure
# 35    Movie                                        Article 15
# 38    Movie                               Kill Me If You Dare
# 44    Movie  American Factory: A Conversation with the Obamas
# 57    Movie                                 The World We Make
# ...     ...                                               ...
# 5451  Movie          Francesco De Carlo: Cose di Questo Mondo
# 5455  Movie                                  The Perfect Date
# 5463  Movie                 Liss Pereira: Reteniendo líquidos
# 5464  Movie                                       The Silence
# 5469  Movie                                               706
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 35               Anubhav Sinha
# 38                Şenol Sönmez
# 44                         NaN
# 57                 Brian Baugh
# ...

# %%
# 5 documentarios mais longos
# será necessario tirar o 'min' dos valores na coluna duration
# Out:
#        type                                              title  \
# 44    Movie   American Factory: A Conversation with the Obamas
# 4878  Movie                                   American Factory
# 2874  Movie                                     The Great Hack
# 531   Movie                                 It Takes a Lunatic
# 666   Movie                               Ghosts of Sugar Land
# 4153  Movie                      The Irishman: In Conversation
# 1659  Movie                                        After Maria
# 2634  Movie                                  Life Overtakes Me
# 1368  Movie                                   Fire in Paradise
# 557   Movie                             Dancing with the Birds
# 5395  Movie                                 The Creative Brain
# 2669  Movie                Oprah Presents When They See Us Now
# 4895  Movie                     Our Planet - Behind The Scenes
# 269   Movie                 Hello, Privilege. It's Me, Chelsea
# ...

# %%
def world_string(title):
    if 'min' in title.lower:
        return
# Out:
#   File "<ipython-input-63-fe44734b4334>", line 1
#     filmes2019['duration'].apply(lambda x: x.del('min'))
#                                                ^
# SyntaxError: invalid syntax

# %%
type(filmes2019['duration'])
# Out:
# pandas.core.series.Series
